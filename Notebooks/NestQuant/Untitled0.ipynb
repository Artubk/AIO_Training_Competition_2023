# %%
y_hat = model(X)

# %%
# post-processing
dự_báo_xu_hướng = Tăng/giảm
ema34 = x
ema89 = y
ema200 = z
if dự_báo_xu_hướng == Tăng:
  => GIá nó phải trên EMA
  if y_hat > ema:
    chúng ta tin vào kết quả model dự đoán
  else:
    if y_(t-1) < ema34:
      y_hat = ema34
    elif y_(t-1) > ema34 && y_(t-1) < ema89:
      y_hat = ema89
    elif y_(t-1) > ema34 && y_(t-1) > ema89:
      y_hat = ema200

# %%
def func_dự_báo_xh():
  flag = True
  if y > đóng xuyên qua ema200: (đóng xuyên lên, đóng xuyên xuống)
    if y: đóng xuyên lên:
      dự_báo_xu_hướng: Tăng
      Flag = True
    else: # y đóng xuyên xuống
      dự_báo_xu_hướng giảm
      Flag = False

  return falg

# %%
if flag == True && dự_báo_xu_hướng == tăng:
  pass
True Tăng
True Giảm
False Giảm
False Tăng

# %%
if y xuyên xuống ema 200:
  dự_báo_xu_hướng = Giảm # cập nhật ngay xu hướng từ tăng thành giảm
  y_hat = model.predict(X)
  if y_hat < ema200:
    tin vào model
  else:
    if y_(t-1) > ema34:
      y_hat = ema34
    elif y_(t-1) < ema34 && y_(t-1) > ema89:
      y_hat = ema89
    elif y_(t-1) < ema34 && y_(t-1) < ema89:
      y_hat = ema200
